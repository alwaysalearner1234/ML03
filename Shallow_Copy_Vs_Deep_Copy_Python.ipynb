# %% [markdown]
# <a href="https://colab.research.google.com/github/alwaysalearner1234/ML03/blob/main/Shallow_Copy_Vs_Deep_Copy_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## =,copy(),deepcopy()
lst1=[1,2,3,4]
lst2=lst1

# %%
lst2[1]=1000

# %%
lst2
# Out:
# [1, 1000, 3, 4]

# %%
lst1
# Out:
# [1, 1000, 3, 4]

# %%
##copy
## Shallow Copy
lst1=[1,2,3,4]
lst2=lst1.copy()

# %%
lst2[1]=1000

# %%
lst2,lst1
# Out:
# ([1, 1000, 3, 4], [1, 2, 3, 4])

# %%
## Shallow Copy nested list
lst1=[[1,2,3,4],[5,6,7,8]]
lst2=lst1.copy()

# %%
lst1[1][0]=100

# %%
lst1
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8]]

# %%
lst1.append([2,3,4,5])

# %%
lst1
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8], [2, 3, 4, 5]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8]]

# %%
##deep copy
import copy
lst1=[1,2,3,4]
lst2=copy.deepcopy(lst1)

# %%
lst2[1]=100

# %%
lst2
# Out:
# [1, 100, 3, 4]

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
### In a normal list shallow ===deep copy

# %%
lst1=[[1,2,3],[3,4,5,],[5,6,7]]
lst2=lst1.copy()

# %%
lst1=[[1,2,3],[3,4,5,],[5,6,7]]
lst2=copy.deepcopy(lst1)

# %%
lst2[1][0]=100

# %%
lst2
# Out:
# [[1, 2, 3], [100, 4, 5], [5, 6, 7]]

# %%
lst1
# Out:
# [[1, 2, 3], [3, 4, 5], [5, 6, 7]]
