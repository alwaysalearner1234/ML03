# %% [markdown]
# <a href="https://colab.research.google.com/github/alwaysalearner1234/ML03/blob/main/Voxel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

# Original NIfTI file path, commented out due to FileNotFoundError
# nii_file = '/data/hohokam/Yanxi/Data/mri2pet/adni/gen/gen_baseline_p32_0_200/m024S4158L081111N73T.nii'
# image = nib.load(nii_file).get_fdata()

# Creating a dummy image for demonstration since the file was not found
image = np.random.rand(128, 128, 128) # Example dummy 3D image

np.nan_to_num(image, copy=False, nan=0.0)

plt.subplot(1, 3, 1)
plt.imshow(np.rot90(image[64, :, :]), cmap='gray')
plt.subplot(1, 3, 2)
plt.imshow(np.rot90(image[:, 64, :]), cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(np.rot90(image[:, :, 64]), cmap='gray')

# Saving to /tmp/ as a generally writable directory
plt.savefig('/tmp/m024S4158L081111N73T.png')

# %%
# !pip install SimpleITK
import SimpleITK as sitk
import matplotlib.pyplot as plt
import nibabel as nib
import numpy as np

# Original NIfTI file path, commented out due to potential FileNotFoundError
# img_file = '/data/hohokam/Yanxi/Data/mri2pet/adni/wmparc_nii/m073S4739L051612N73TCF/wmparc.nii'
# img = nib.load(img_file).get_fdata()

# Creating a dummy image for demonstration since the file was not found
img = np.random.rand(128, 128, 128) # Example dummy 3D image

np.nan_to_num(img, copy=False, nan=0.0)
plt.imshow(np.rot90(img[:, :, 64]))

# Using the dummy image for V_wmparc as well
V_wmparc = img

CBmask=np.zeros(V_wmparc.shape)
CBWmask=np.array(CBmask,copy=True)
# Out:
# Collecting SimpleITK
#   Downloading simpleitk-2.5.6-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.4 kB)
# Downloading simpleitk-2.5.6-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (52.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 MB 18.4 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.5.6

# %%
import matplotlib.pyplot as plt
import numpy as np # Import numpy if not already imported

# Define dummy images for plotting, similar to previous cells
mri_image = np.random.rand(128, 128, 128)
pet_image = np.random.rand(128, 128, 128)
gen_image = np.random.rand(128, 128, 128)
mask_image = np.random.rand(128, 128, 128)

cols = ['MRI', 'Real PET', 'Synthesized PET', 'Mask']
rows = ['Axial', 'Coronal', 'Sagital']

fig, axes = plt.subplots(nrows=3, ncols=4)
# plt.subplots_adjust(top = 0.7, bottom=0.0, hspace=0.05, wspace=-0.25)

for ax, col in zip(axes[0], cols):
    ax.set_title(col)

for ax, row in zip(axes[:,0], rows):
    ax.set_ylabel(row)

plt.setp(axes, xticks=[], yticks=[])
# fig.subplots_adjust(left=2.0, right=15.0)

plt.subplot(3, 4, 1)
plt.imshow(np.rot90(mri_image[:, :, 64]), cmap='gray')
plt.subplot(3, 4, 2)
plt.imshow(np.rot90(pet_image[:, :, 64]), cmap='gray')
plt.subplot(3, 4, 3)
plt.imshow(np.rot90(gen_image[:, :, 64]), cmap='gray')
plt.subplot(3, 4, 4)
plt.imshow(np.rot90(mask_image[:, :, 64]), cmap='gray')

plt.subplot(3, 4, 5)
plt.imshow(np.rot90(mri_image[:, 64, :]), cmap='gray')
plt.subplot(3, 4, 6)
plt.imshow(np.rot90(pet_image[:, 64, :]), cmap='gray')
plt.subplot(3, 4, 7)
plt.imshow(np.rot90(gen_image[:, 64, :]), cmap='gray')
plt.subplot(3, 4, 8)
plt.imshow(np.rot90(mask_image[:, 64, :]), cmap='gray')

plt.subplot(3, 4, 9)
plt.imshow(np.rot90(mri_image[64, :, :]), cmap='gray')
plt.subplot(3, 4, 10)
plt.imshow(np.rot90(pet_image[64, :, :]), cmap='gray')
plt.subplot(3, 4, 11)
plt.imshow(np.rot90(gen_image[64, :, :]), cmap='gray')
plt.subplot(3, 4, 12)
plt.imshow(np.rot90(mask_image[64, :, :]), cmap='gray')

plt.tight_layout()
plt.show()
plt.savefig('/tmp/all.png')
