# %% [markdown]
# <a href="https://colab.research.google.com/github/alwaysalearner1234/ML03/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://www.pexels.com/video/people-walking-in-a-busy-street-at-hongdae-8275531/
# https://raw.githubusercontent.com/matlab-deep-learning/Object-Detection-Using-Pretrained-YOLO-v2/refs/heads/main/%2Bhelper/coco-classes.txt

# %%
# !pip install ultralytics --quiet

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'index.html.1',
#  'yolo11n.pt',
#  'video1.mp4',
#  'video.mp4',
#  'runs',
#  'index.html',
#  'kang.mp4',
#  'kangana.mp4',
#  'video56.mp4',
#  'sample_data']

# %%
from ultralytics import YOLO
model=YOLO('yolo11n.pt')

# %%
# !wget https://www.pexels.com/download/video/36437257/ -O video.mp4
# Out:
# --2026-07-30 09:55:16--  https://www.pexels.com/download/video/36437257/
# Resolving www.pexels.com (www.pexels.com)... 104.18.66.220, 104.18.67.220, 2606:4700::6812:42dc, ...
# Connecting to www.pexels.com (www.pexels.com)|104.18.66.220|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://videos.pexels.com/video-files/36437257/15451161_3840_2160_50fps.mp4 [following]
# --2026-07-30 09:55:16--  https://videos.pexels.com/video-files/36437257/15451161_3840_2160_50fps.mp4
# Resolving videos.pexels.com (videos.pexels.com)... 104.18.67.220, 104.18.66.220, 2606:4700::6812:42dc, ...
# Connecting to videos.pexels.com (videos.pexels.com)|104.18.67.220|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75965343 (72M) [video/mp4]
# Saving to: ‘video.mp4’
#
# video.mp4           100%[===================>]  72.45M   208MB/s    in 0.3s
#
# 2026-07-30 09:55:17 (208 MB/s) - ‘video.mp4’ saved [75965343/75965343]

# %%
results = model("/content/video.mp4",show=True,save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/520) /content/video.mp4: 384x640 7 persons, 1112.1ms
# video 1/1 (frame 2/520) /content/video.mp4: 384x640 9 persons, 1 car, 654.7ms
# video 1/1 (frame 3/520) /content/video.mp4: 384x640 9 persons, 495.4ms
# video 1/1 (frame 4/520) /content/video.mp4: 384x640 11 persons, 227.1ms
# ...
